# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 6</font>
#
# ## Download: http://github.com/dsacademybr

# %% [markdown]
# ## Stream de Dados do Twitter com MongoDB, Pandas e Scikit Learn

# %% [markdown]
# ## Preparando a Conexão com o Twitter

# %%
# Instala o pacote tweepy
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in c:\users\felipe\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\felipe\anaconda3\lib\site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: requests>=2.11.1 in c:\users\felipe\anaconda3\lib\site-packages (from tweepy) (2.24.0)
# Requirement already satisfied: PySocks>=1.5.7 in c:\users\felipe\anaconda3\lib\site-packages (from tweepy) (1.6.8)
# Requirement already satisfied: six>=1.10.0 in c:\users\felipe\anaconda3\lib\site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\felipe\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\felipe\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\felipe\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\felipe\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\felipe\anaconda3\lib\site-packages (from requests>=2.11.1->tweepy) (2.6)
# WARNING: You are using pip version 20.1.1; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\felipe\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
# Importando os módulos Tweepy, Datetime e Json
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
from datetime import datetime
import json

# %% [markdown]
# Veja no manual em pdf como criar sua API no Twitter e configure as suas chaves abaixo.

# %%
# Adicione aqui sua Consumer Key
consumer_key = "Chave"

# %%
# Adicione aqui sua Consumer Secret 
consumer_secret = "Chave"

# %%
# Adicione aqui seu Access Token
access_token = "Chave"

# %%
# Adicione aqui seu Access Token Secret
access_token_secret = "Chave"

# %%
# Criando as chaves de autenticação
auth = OAuthHandler(consumer_key, consumer_secret)

# %%
auth.set_access_token(access_token, access_token_secret)

# %%
# Criando uma classe para capturar os stream de dados do Twitter e 
# armazenar no MongoDB
class MyListener(StreamListener):
    def on_data(self, dados):
        tweet = json.loads(dados)
        created_at = tweet["created_at"]
        id_str = tweet["id_str"]
        text = tweet["text"]
        obj = {"created_at":created_at,"id_str":id_str,"text":text,}
        tweetind = col.insert_one(obj).inserted_id
        print (obj)
        return True

# %%
# Criando o objeto mylistener
mylistener = MyListener()

# %%
# Criando o objeto mystream
mystream = Stream(auth, listener = mylistener)

# %% [markdown]
# ## Preparando a Conexão com o MongoDB

# %%
# Importando do PyMongo o módulo MongoClient
from pymongo import MongoClient

# %%
# Criando a conexão ao MongoDB
client = MongoClient('localhost', 27017)

# %%
# Criando o banco de dados twitterdb
db = client.twitterdb

# %%
# Criando a collection "col"
col = db.tweets

# %%
# Criando uma lista de palavras chave para buscar nos Tweets
keywords = ['Big Data', 'Python', 'Data Mining', 'Data Science']

# %%
# Iniciando o filtro e gravando os tweets no MongoDB
mystream.filter(track=keywords)
# Out:
# {'created_at': 'Fri Jan 08 18:57:00 +0000 2021', 'id_str': '1347618322435682304', 'text': 'RT @NTSlive: CDMX Tapes ( @N_A_A_F_I ) is taking over ch2 for the next couple hours w/ mixes from DJ Python, DJ Dirt, Ezra Miller &amp; Manriqu…', '_id': ObjectId('5ff8ab03aab824ab152c8147')}
# {'created_at': 'Fri Jan 08 18:57:02 +0000 2021', 'id_str': '1347618331503845376', 'text': 'RT @iampriyapareek: https://t.co/oVwifCYCgg\n#100DaysOfCode #javascript #rstats #MachineLearning #DEV #Python #DevOps #Developer #webinar #W…', '_id': ObjectId('5ff8ab05aab824ab152c8148')}
# {'created_at': 'Fri Jan 08 18:57:02 +0000 2021', 'id_str': '1347618332460150784', 'text': 'RT @Paula_Piccard: Five real world AI and machine learning trends that will make an impact in 2021 \n\n#MachineLearning #Python #AI #100DaysO…', '_id': ObjectId('5ff8ab06aab824ab152c8149')}
# {'created_at': 'Fri Jan 08 18:57:02 +0000 2021', 'id_str': '1347618332455952385', 'text': 'RT @machinelearnTec: SIGNIFICANT BENEFITS OF GEOSPATIAL INFORMATION AND BIG DATA ANALYTICS https://t.co/LBi4iWRRmW\n\n#MachineLearning #DataS…', '_id': ObjectId('5ff8ab06aab824ab152c814a')}
# {'created_at': 'Fri Jan 08 18:57:02 +0000 2021', 'id_str': '1347618332455927811', 'text': 'RT @machinelearnTec: SIGNIFICANT BENEFITS OF GEOSPATIAL INFORMATION AND BIG DATA ANALYTICS https://t.co/LBi4iWRRmW\n\n#MachineLearning #DataS…', '_id': ObjectId('5ff8ab06aab824ab152c814b')}
# {'created_at': 'Fri Jan 08 18:57:02 +0000 2021', 'id_str': '1347618332489502723', 'text': 'RT @machinelearnTec: SIGNIFICANT BENEFITS OF GEOSPATIAL INFORMATION AND BIG DATA ANALYTICS https://t.co/LBi4iWRRmW\n\n#MachineLearning #DataS…', '_id': ObjectId('5ff8ab06aab824ab152c814c')}
# {'created_at': 'Fri Jan 08 18:57:05 +0000 2021', 'id_str': '1347618343101091842', 'text': 'RT @machinelearnTec: SIGNIFICANT BENEFITS OF GEOSPATIAL INFORMATION AND BIG DATA ANALYTICS https://t.co/LBi4iWRRmW\n\n#MachineLearning #DataS…', '_id': ObjectId('5ff8ab08aab824ab152c814d')}
# {'created_at': 'Fri Jan 08 18:57:07 +0000 2021', 'id_str': '1347618353393897474', 'text': 'فا نزلت في شهر رمضان اخد كورس Python مع ناس صحابي في سنتر شهاب الله يمسيه بالخير روحت مرتين تلاته واتعولقت بصراحه ب… https://t.co/GUZPIp0tH3', '_id': ObjectId('5ff8ab0baab824ab152c814e')}
# {'created_at': 'Fri Jan 08 18:57:09 +0000 2021', 'id_str': '1347618362696691712', 'text': 'D21: Implemented queue in Python with Python classes.\nYou can find the code at : https://t.co/enWazlpk3Z\n\n#Python #100DaysOfCode #h3avren', '_id': ObjectId('5ff8ab0daab824ab152c814f')}
# {'created_at': 'Fri Jan 08 18:57:11 +0000 2021', 'id_str': '1347618368153649155', 'text': 'RT @NTSlive: CDMX Tapes ( @N_A_A_F_I ) is taking over ch2 for the next couple hours w/ mixes from DJ Python, DJ Dirt, Ezra Miller &amp; Manriqu…', '_id': ObjectId('5ff8ab0eaab824ab152c8150')}
# {'created_at': 'Fri Jan 08 18:57:11 +0000 2021', 'id_str': '1347618369470689292', 'text': 'RT @slpng_giants: One more time for everyone in our mentions today:\n\nNONE OF THESE PLATFORMS OWE YOU A THING. \n\nTHEY ARE NOT PUBLIC SQUARES…', '_id': ObjectId('5ff8ab0eaab824ab152c8151')}
# {'created_at': 'Fri Jan 08 18:57:13 +0000 2021', 'id_str': '1347618376370315264', 'text': 'Complete Image Augmentation using OpenCV in Python\n\n☞ https://t.co/a3b8FtZoLQ\n\n#OpenCV #Python #Morioh https://t.co/OlYt3rMF3e', '_id': ObjectId('5ff8ab10aab824ab152c8152')}
# {'created_at': 'Fri Jan 08 18:57:13 +0000 2021', 'id_str': '1347618378509410306', 'text': 'RT @toluolawumi_: 1. Angular JS Developers needed for a 50-hour contract gig. \n\n2. Onsite Python Developers needed for a full time role at…', '_id': ObjectId('5ff8ab10aab824ab152c8153')}
# {'created_at': 'Fri Jan 08 18:57:15 +0000 2021', 'id_str': '1347618384389828612', 'text': 'RT @h3avren: D21: Implemented queue in Python with Python classes.\nYou can find the code at : https://t.co/enWazlpk3Z\n\n#Python #100DaysOfCo…', '_id': ObjectId('5ff8ab12aab824ab152c8154')}
# {'created_at': 'Fri Jan 08 18:57:15 +0000 2021', 'id_str': '1347618384498872323', 'text': 'RT @h3avren: D21: Implemented queue in Python with Python classes.\nYou can find the code at : https://t.co/enWazlpk3Z\n\n#Python #100DaysOfCo…', '_id': ObjectId('5ff8ab12aab824ab152c8155')}
# {'created_at': 'Fri Jan 08 18:57:15 +0000 2021', 'id_str': '1347618384666624000', 'text': 'RT @h3avren: D21: Implemented queue in Python with Python classes.\nYou can find the code at : https://t.co/enWazlpk3Z\n\n#Python #100DaysOfCo…', '_id': ObjectId('5ff8ab12aab824ab152c8156')}
# {'created_at': 'Fri Jan 08 18:57:15 +0000 2021', 'id_str': '1347618384679231490', 'text': 'RT @h3avren: D21: Implemented queue in Python with Python classes.\nYou can find the code at : https://t.co/enWazlpk3Z\n\n#Python #100DaysOfCo…', '_id': ObjectId('5ff8ab12aab824ab152c8157')}
# {'created_at': 'Fri Jan 08 18:57:15 +0000 2021', 'id_str': '1347618384729550849', 'text': 'RT @h3avren: D21: Implemented queue in Python with Python classes.\nYou can find the code at : https://t.co/enWazlpk3Z\n\n#Python #100DaysOfCo…', '_id': ObjectId('5ff8ab12aab824ab152c8158')}
# {'created_at': 'Fri Jan 08 18:57:15 +0000 2021', 'id_str': '1347618384817627144', 'text': 'RT @VeritasTXgem: 2167. Rt.@KanekoaTheGreat \nGEORGIA🚨\nNeg. votes &amp; vote switches should *NEVER* happen on CNN, ABC, &amp; NBC live feeds. Accor…', '_id': ObjectId('5ff8ab12aab824ab152c8159')}
# {'created_at': 'Fri Jan 08 18:57:16 +0000 2021', 'id_str': '1347618390320545798', 'text': 'RT @h3avren: D21: Implemented queue in Python with Python classes.\nYou can find the code at : https://t.co/enWazlpk3Z\n\n#Python #100DaysOfCo…', '_id': ObjectId('5ff8ab13aab824ab152c815a')}
# {'created_at': 'Fri Jan 08 18:57:17 +0000 2021', 'id_str': '1347618396448419841', 'text': '@WKCosmo @carolynporco Measurements are &gt;&gt;&gt; more important than theory. Time to accept there is a difference betwee… https://t.co/cy1jmLe6Ik', '_id': ObjectId('5ff8ab15aab824ab152c815b')}
# {'created_at': 'Fri Jan 08 18:57:20 +0000 2021', 'id_str': '1347618408389607426', 'text': "RT @DevDailyy: 📢ANNOUNCEMENT📢\n\nFounder of freeCodeCamp @ossia will be making a feature in this week's email digest!\n\nMake sure you subscrib…", '_id': ObjectId('5ff8ab18aab824ab152c815c')}
# {'created_at': 'Fri Jan 08 18:57:20 +0000 2021', 'id_str': '1347618408435740672', 'text': 'RT @h3avren: D21: Implemented queue in Python with Python classes.\nYou can find the code at : https://t.co/enWazlpk3Z\n\n#Python #100DaysOfCo…', '_id': ObjectId('5ff8ab18aab824ab152c815d')}
# {'created_at': 'Fri Jan 08 18:57:21 +0000 2021', 'id_str': '1347618409643601920', 'text': 'RT @akagami_channel: 今日リサーチで得た商品知識が来年や10年後も同じように活用可。\n\nこれがアンティークの良いところ。知識が蓄積されて強くなっていきます。つまり時給が上がっていきます。\n\n「ド中古」であるがために新品のトレンドと全く関係が無い世界。最新版が…', '_id': ObjectId('5ff8ab18aab824ab152c815e')}
# {'created_at': 'Fri Jan 08 18:57:22 +0000 2021', 'id_str': '1347618414681083906', 'text': "RT @DevDailyy: 📢ANNOUNCEMENT📢\n\nFounder of freeCodeCamp @ossia will be making a feature in this week's email digest!\n\nMake sure you subscrib…", '_id': ObjectId('5ff8ab19aab824ab152c815f')}
# {'created_at': 'Fri Jan 08 18:57:23 +0000 2021', 'id_str': '1347618421840732160', 'text': 'RT @MehrishY: Day7: Python Learning \nSo like old C lang times, created shapes with nested for loops and conditional statements. \nNo progres…', '_id': ObjectId('5ff8ab1baab824ab152c8160')}
# {'created_at': 'Fri Jan 08 18:57:29 +0000 2021', 'id_str': '1347618445081251841', 'text': 'RT @MehrishY: Day7: Python Learning \nSo like old C lang times, created shapes with nested for loops and conditional statements. \nNo progres…', '_id': ObjectId('5ff8ab20aab824ab152c8161')}
# {'created_at': 'Fri Jan 08 18:57:31 +0000 2021', 'id_str': '1347618452673069061', 'text': '🔹CURSO PROGRAMACIÓN DE #DJANGO3🔹\n📅Nueva convocatoria en febrero, a través de #AulaVirtual, siendo las… https://t.co/H9wVgAjQ2B', '_id': ObjectId('5ff8ab22aab824ab152c8162')}
# {'created_at': 'Fri Jan 08 18:57:33 +0000 2021', 'id_str': '1347618463850762240', 'text': 'RT @CoreysDigs: 5) VIDEO summary of chapter 3 in full, plus a comprehensive background on how they are ruling every facet of the healthcare…', '_id': ObjectId('5ff8ab25aab824ab152c8163')}
# {'created_at': 'Fri Jan 08 18:57:42 +0000 2021', 'id_str': '1347618500211138565', 'text': 'WE RULE!', '_id': ObjectId('5ff8ab2eaab824ab152c8164')}
# {'created_at': 'Fri Jan 08 18:57:46 +0000 2021', 'id_str': '1347618517311479813', 'text': 'RT @AlexRosu1989: #iot #software #code #CodeNewbie  #100DaysOfCode #javascript #programming #BigData #ai #Serverless #coding #Cloud #code #…', '_id': ObjectId('5ff8ab32aab824ab152c8165')}
# {'created_at': 'Fri Jan 08 18:57:47 +0000 2021', 'id_str': '1347618518921998336', 'text': 'RT @dillonliam: A nice, succinct graphic from @ApartmentList showing the big rent declines in large cities and big rent hikes in smaller ci…', '_id': ObjectId('5ff8ab32aab824ab152c8166')}
# {'created_at': 'Fri Jan 08 18:57:47 +0000 2021', 'id_str': '1347618521660928000', 'text': 'RT @slpng_giants: One more time for everyone in our mentions today:\n\nNONE OF THESE PLATFORMS OWE YOU A THING. \n\nTHEY ARE NOT PUBLIC SQUARES…', '_id': ObjectId('5ff8ab33aab824ab152c8167')}
# {'created_at': 'Fri Jan 08 18:57:51 +0000 2021', 'id_str': '1347618537855180803', 'text': 'Python programlama dili kullanan kişiler neden bu kadar agresif halbuki noktalı virgülde kullanmaya gerek yok ama 😂', '_id': ObjectId('5ff8ab36aab824ab152c8168')}
# {'created_at': 'Fri Jan 08 18:58:00 +0000 2021', 'id_str': '1347618574517596174', 'text': 'Time : 2021-01-08T18:58:00.2642451Z\n\n#Coding Test now.\n#Someone #dark #Python #C++ #Telegram #facebook #twitter… https://t.co/sP2ijK7tMM', '_id': ObjectId('5ff8ab3faab824ab152c8169')}
# {'created_at': 'Fri Jan 08 18:58:02 +0000 2021', 'id_str': '1347618582532911106', 'text': 'Checkout CursorTek is #selling #bulk #data of 3k plus #categories like:\n\n#bars #hotels #restaurants #plumbers… https://t.co/qQCkVXQtjP', '_id': ObjectId('5ff8ab41aab824ab152c816a')}
# {'created_at': 'Fri Jan 08 18:58:05 +0000 2021', 'id_str': '1347618596713848838', 'text': 'RT @GeeknProud42: WANTED! \nSomeone who can take dictation of python/bash/LaTeX to assist me with the final year of my #PhD !\nWork is remote…', '_id': ObjectId('5ff8ab45aab824ab152c816b')}
# {'created_at': 'Fri Jan 08 18:58:05 +0000 2021', 'id_str': '1347618597376413696', 'text': '予想数字公開中!!\nAI言語Pythonにてプログラミング!!\n\n○ロト6→毎週月・木\n○ロト7→毎週金曜\n\nhttps://t.co/SH77B0jCBQ\n\n【お願い】\n#フォロー\n#固定リツイート\n\n【お返し】\n#フォローバック\n#固定リツイート\n\n#フォロバ100\n#相互', '_id': ObjectId('5ff8ab45aab824ab152c816c')}
# {'created_at': 'Fri Jan 08 18:58:06 +0000 2021', 'id_str': '1347618599033253891', 'text': 'RT @DynamicWebPaige: 😮 Oh, wow - this is also rad: make changes to a spreadsheet with @TryMito, and generate Python equivalent functions:…', '_id': ObjectId('5ff8ab45aab824ab152c816d')}
# {'created_at': 'Fri Jan 08 18:58:06 +0000 2021', 'id_str': '1347618600836861953', 'text': '\U0001f9d0😷💉🚨👇🐍Big Tech and Big Pharma Merge: Oracle Takes Over Vaccine Data World\n@randyhillier @impulsivewoman @BeNosey \nhttps://t.co/1qUkO7OxWO', '_id': ObjectId('5ff8ab46aab824ab152c816e')}
# {'created_at': 'Fri Jan 08 18:58:09 +0000 2021', 'id_str': '1347618612400386049', 'text': 'If you’re into data, science or learning you should check out my #DataScience Twitter account where I’m doing the… https://t.co/596IAamHA4', '_id': ObjectId('5ff8ab48aab824ab152c816f')}
# {'created_at': 'Fri Jan 08 18:58:11 +0000 2021', 'id_str': '1347618620428476418', 'text': "What the hell, I'm game. Ok, so I can safely say Mr. Show, Monty Python, Hogan's Heroes, Harvey Birdman, The Brak S… https://t.co/VWAUVLceH7", '_id': ObjectId('5ff8ab4aaab824ab152c8170')}
# {'created_at': 'Fri Jan 08 18:58:16 +0000 2021', 'id_str': '1347618642171596801', 'text': 'RT @Colinbradley111: If you’re into data, science or learning you should check out my #DataScience Twitter account where I’m doing the #66d…', '_id': ObjectId('5ff8ab4faab824ab152c8171')}
# {'created_at': 'Fri Jan 08 18:58:17 +0000 2021', 'id_str': '1347618646873485315', 'text': 'RT @hardmaru: Every trading desk’s dream, and risk management team’s nightmare:', '_id': ObjectId('5ff8ab50aab824ab152c8172')}
# {'created_at': 'Fri Jan 08 18:58:25 +0000 2021', 'id_str': '1347618678636998657', 'text': 'RT @TeachTheMachine: Naive Bayes Classifier From Scratch in Python https://t.co/1yMaeQQL1O https://t.co/OYSpxjTjSU', '_id': ObjectId('5ff8ab58aab824ab152c8173')}
# {'created_at': 'Fri Jan 08 18:58:29 +0000 2021', 'id_str': '1347618698513809416', 'text': 'Blog Spot Update:\nhttps://t.co/gaaNJjIw6A\nStill playing with NXT and USD my two favorite opensource projects!\n#NXT… https://t.co/B3XSboSZpE', '_id': ObjectId('5ff8ab5daab824ab152c8174')}
# {'created_at': 'Fri Jan 08 18:58:33 +0000 2021', 'id_str': '1347618712820588546', 'text': 'Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript… https://t.co/9dc5DYBSV4', '_id': ObjectId('5ff8ab60aab824ab152c8175')}
# {'created_at': 'Fri Jan 08 18:58:33 +0000 2021', 'id_str': '1347618714670276608', 'text': 'RT @TahaYasseri: 36 fully funded (four years of tuition fee + an annual stipend of €18,500) structured PhD positions in \nFoundations of Dat…', '_id': ObjectId('5ff8ab61aab824ab152c8176')}
# {'created_at': 'Fri Jan 08 18:58:34 +0000 2021', 'id_str': '1347618717560156161', 'text': 'RT @Tanguy_lrx: Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript #github #nod…', '_id': ObjectId('5ff8ab61aab824ab152c8177')}
# {'created_at': 'Fri Jan 08 18:58:34 +0000 2021', 'id_str': '1347618717761495041', 'text': "Nemours Children's Health System had a big challenge around electronic information: It needed to change its culture… https://t.co/JK3TBVKKql", '_id': ObjectId('5ff8ab61aab824ab152c8178')}
# {'created_at': 'Fri Jan 08 18:58:36 +0000 2021', 'id_str': '1347618725999104005', 'text': 'RT @Tanguy_lrx: Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript #github #nod…', '_id': ObjectId('5ff8ab63aab824ab152c8179')}
# {'created_at': 'Fri Jan 08 18:58:36 +0000 2021', 'id_str': '1347618727592943617', 'text': 'RT @CodingByCarson: Reddit is a warzone, never go there, everyone’s answer is probably Stack Overflow. https://t.co/DAqPMPvSK1', '_id': ObjectId('5ff8ab64aab824ab152c817a')}
# {'created_at': 'Fri Jan 08 18:58:38 +0000 2021', 'id_str': '1347618734651928577', 'text': 'RT @Tanguy_lrx: Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript #github #nod…', '_id': ObjectId('5ff8ab65aab824ab152c817b')}
# {'created_at': 'Fri Jan 08 18:58:38 +0000 2021', 'id_str': '1347618734790356999', 'text': 'RT @Tanguy_lrx: Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript #github #nod…', '_id': ObjectId('5ff8ab65aab824ab152c817c')}
# {'created_at': 'Fri Jan 08 18:58:40 +0000 2021', 'id_str': '1347618743518597121', 'text': 'RT @UndergroundSilk: The Chinese were talking about it immediately with extreme confidence \U0001f9d0\n\nhttps://t.co/kC89Q8XDY8 https://t.co/IWu45Yz1…', '_id': ObjectId('5ff8ab68aab824ab152c817d')}
# {'created_at': 'Fri Jan 08 18:58:41 +0000 2021', 'id_str': '1347618747285000193', 'text': 'Love me some data and Presidents who actually look at things like data and science and stuff that proves things...', '_id': ObjectId('5ff8ab68aab824ab152c817e')}
# {'created_at': 'Fri Jan 08 18:58:48 +0000 2021', 'id_str': '1347618776364187648', 'text': 'RT @DonnaDemure: Love me some data and Presidents who actually look at things like data and science and stuff that proves things... https:/…', '_id': ObjectId('5ff8ab6faab824ab152c817f')}
# {'created_at': 'Fri Jan 08 18:58:49 +0000 2021', 'id_str': '1347618782361972736', 'text': 'lgsg sadja ke part oom budi mengatakan "buat saya, sampai sekarang saya belum tau mana yang benar." 🤣 sudah menjela… https://t.co/TajSaWVABZ', '_id': ObjectId('5ff8ab71aab824ab152c8180')}
# {'created_at': 'Fri Jan 08 18:58:51 +0000 2021', 'id_str': '1347618789232242689', 'text': 'RT @akagami_channel: 今日リサーチで得た商品知識が来年や10年後も同じように活用可。\n\nこれがアンティークの良いところ。知識が蓄積されて強くなっていきます。つまり時給が上がっていきます。\n\n「ド中古」であるがために新品のトレンドと全く関係が無い世界。最新版が…', '_id': ObjectId('5ff8ab72aab824ab152c8181')}
# {'created_at': 'Fri Jan 08 18:58:53 +0000 2021', 'id_str': '1347618798292107265', 'text': 'Well, Monty python fans, I’m starting to feel a bit like the knight. I can still think and talk, but my limbs, well… https://t.co/kfEx0F8TmC', '_id': ObjectId('5ff8ab75aab824ab152c8182')}
# {'created_at': 'Fri Jan 08 18:59:01 +0000 2021', 'id_str': '1347618832840593408', 'text': 'RT @Tanguy_lrx: Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript #github #nod…', '_id': ObjectId('5ff8ab7daab824ab152c8183')}
# {'created_at': 'Fri Jan 08 18:59:01 +0000 2021', 'id_str': '1347618832769286146', 'text': 'I just entered to win a Sig Sauer MPX Copperhead &amp; Colt Python Revolver from @ClassicFirearm! Valued At $3500!… https://t.co/wgEFcglJt6', '_id': ObjectId('5ff8ab7daab824ab152c8184')}
# {'created_at': 'Fri Jan 08 18:59:04 +0000 2021', 'id_str': '1347618843125047299', 'text': 'RT @BlackfreeNiken: Master Designing, Integrating &amp; Deploying Enterprise AI Apps\n\n⏩⏩⏩ https://t.co/cOuvzTsclr\n\n#DeepLearning #Analytics #Da…', '_id': ObjectId('5ff8ab7faab824ab152c8185')}
# {'created_at': 'Fri Jan 08 18:59:06 +0000 2021', 'id_str': '1347618851773534208', 'text': 'RT @odbmsorg: "“Professor Zicari and his team are developing  an ethical framework to identify the moral hazards of AI."\n--— CAPCO INSTITUT…', '_id': ObjectId('5ff8ab81aab824ab152c8186')}
# {'created_at': 'Fri Jan 08 18:59:06 +0000 2021', 'id_str': '1347618852277018624', 'text': 'RT @BlackfreeNiken: Master Designing, Integrating &amp; Deploying Enterprise AI Apps\n\n⏩⏩⏩ https://t.co/cOuvzTsclr\n\n#DeepLearning #Analytics #Da…', '_id': ObjectId('5ff8ab81aab824ab152c8187')}
# {'created_at': 'Fri Jan 08 18:59:07 +0000 2021', 'id_str': '1347618856194420738', 'text': 'RT @cherylwatson919: I just entered to win a Sig Sauer MPX Copperhead &amp; Colt Python Revolver from @ClassicFirearm! Valued At $3500! #sweeps…', '_id': ObjectId('5ff8ab82aab824ab152c8188')}
# {'created_at': 'Fri Jan 08 18:59:12 +0000 2021', 'id_str': '1347618876662706181', 'text': 'I just entered to win a Sig Sauer MPX Copperhead &amp; Colt Python Revolver from @ClassicFirearm! Valued At $3500!… https://t.co/8mDFWyAJzT', '_id': ObjectId('5ff8ab87aab824ab152c8189')}
# {'created_at': 'Fri Jan 08 18:59:13 +0000 2021', 'id_str': '1347618881301577728', 'text': 'RT @TeachTheMachine: Naive Bayes Classifier From Scratch in Python https://t.co/1yMaeQQL1O https://t.co/OYSpxjTjSU', '_id': ObjectId('5ff8ab88aab824ab152c818a')}
# {'created_at': 'Fri Jan 08 18:59:15 +0000 2021', 'id_str': '1347618888708743173', 'text': 'The data on the risk relates to adults with #Downsyndrome, but there is no evidence to say otherwise for children.… https://t.co/DSF4XAsQGV', '_id': ObjectId('5ff8ab8aaab824ab152c818b')}
# {'created_at': 'Fri Jan 08 18:59:15 +0000 2021', 'id_str': '1347618891426648065', 'text': 'RT @Tanguy_lrx: Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript #github #nod…', '_id': ObjectId('5ff8ab8baab824ab152c818c')}
# {'created_at': 'Fri Jan 08 18:59:17 +0000 2021', 'id_str': '1347618898720530436', 'text': 'RT @blueldr: I just entered to win a Sig Sauer MPX Copperhead &amp; Colt Python Revolver from @ClassicFirearm! Valued At $3500! #sweepstakes #S…', '_id': ObjectId('5ff8ab8daab824ab152c818d')}
# {'created_at': 'Fri Jan 08 18:59:20 +0000 2021', 'id_str': '1347618909432782848', 'text': 'RT @Analytics_699: Agentless IoT/OT security solutions via Azure Defender ▶️\n#Analytics #MachineLearning #AI #Python #Rstats #Reactjs #IoT…', '_id': ObjectId('5ff8ab8faab824ab152c818e')}
# {'created_at': 'Fri Jan 08 18:59:20 +0000 2021', 'id_str': '1347618912683352064', 'text': 'RT @Tanguy_lrx: Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript #github #nod…', '_id': ObjectId('5ff8ab90aab824ab152c818f')}
# {'created_at': 'Fri Jan 08 18:59:22 +0000 2021', 'id_str': '1347618918387613697', 'text': 'RT @Tanguy_lrx: Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript #github #nod…', '_id': ObjectId('5ff8ab91aab824ab152c8190')}
# {'created_at': 'Fri Jan 08 18:59:22 +0000 2021', 'id_str': '1347618918781751297', 'text': 'RT @TommyLeblancB: The data on the risk relates to adults with #Downsyndrome, but there is no evidence to say otherwise for children. Also…', '_id': ObjectId('5ff8ab91aab824ab152c8191')}
# {'created_at': 'Fri Jan 08 18:59:24 +0000 2021', 'id_str': '1347618929389219842', 'text': "Besoin de stage de 1ère année dans le dev. Toutes les demandes que j'ai reçu sont pour du bac+3/bac+5...\nJ'suis prê… https://t.co/f53hprOB44", '_id': ObjectId('5ff8ab94aab824ab152c8192')}
# {'created_at': 'Fri Jan 08 18:59:29 +0000 2021', 'id_str': '1347618949421273092', 'text': 'RT @Kada_soulayman: Time : 2021-01-08T18:58:00.2642451Z\n\n#Coding Test now.\n#Someone #dark #Python #C++ #Telegram #facebook #twitter #instag…', '_id': ObjectId('5ff8ab99aab824ab152c8193')}
# {'created_at': 'Fri Jan 08 18:59:29 +0000 2021', 'id_str': '1347618950092267520', 'text': '✨Decisions, decisions: How to choose between so many big data tools\n\n🔭https://t.co/3kW0cHKfRg -', '_id': ObjectId('5ff8ab99aab824ab152c8194')}
# {'created_at': 'Fri Jan 08 18:59:30 +0000 2021', 'id_str': '1347618951006539776', 'text': "God, I can't wait until a year from now when all the information comes out about how ass backwards our covid respon… https://t.co/SVAPuJnGpS", '_id': ObjectId('5ff8ab99aab824ab152c8195')}
# {'created_at': 'Fri Jan 08 18:59:33 +0000 2021', 'id_str': '1347618964600311808', 'text': '最近の開発スタイルはVS Codeに依存していて、WinとLinuxで検証しながら、はじめはPythonで実験を検討していて、よさげになったら、C/C++で書き直すっていうスタイルが定着してきた。\n\nボクだけがそうなのか？と思った… https://t.co/MFE1tOzYiM', '_id': ObjectId('5ff8ab9caab824ab152c8196')}
# {'created_at': 'Fri Jan 08 18:59:37 +0000 2021', 'id_str': '1347618980257624064', 'text': "RT @DrewBurgan: God, I can't wait until a year from now when all the information comes out about how ass backwards our covid response was.…", '_id': ObjectId('5ff8aba0aab824ab152c8197')}
# {'created_at': 'Fri Jan 08 18:59:37 +0000 2021', 'id_str': '1347618981138497536', 'text': 'RT @usdatascientist: 全員に最適なロードマップはないですが，全くの初心者がAI開発を目指す順序は以下\n\n1. タッチタイピング\n2.Git&amp;Docker\n3.Python基礎\n4.Pythonライブラリ\n5.統計学\n5.5.(微積・線形代数)\n6.機械学習…', '_id': ObjectId('5ff8aba0aab824ab152c8198')}
# {'created_at': 'Fri Jan 08 18:59:38 +0000 2021', 'id_str': '1347618987895648262', 'text': '@kieran_hurley Deaths per 100k of population here. https://t.co/mgFxjRqZ6J\n\nThe really big countries with populist… https://t.co/ampA57YtY8', '_id': ObjectId('5ff8aba2aab824ab152c8199')}
# {'created_at': 'Fri Jan 08 18:59:40 +0000 2021', 'id_str': '1347618996061835264', 'text': "RT @MelissaSantos1: I know there's a lot of news this week. But check out what I learned from Federal Election Commission data: WA resident…", '_id': ObjectId('5ff8aba4aab824ab152c819a')}
# {'created_at': 'Fri Jan 08 18:59:41 +0000 2021', 'id_str': '1347618997177446400', 'text': 'RT @slpng_giants: One more time for everyone in our mentions today:\n\nNONE OF THESE PLATFORMS OWE YOU A THING. \n\nTHEY ARE NOT PUBLIC SQUARES…', '_id': ObjectId('5ff8aba4aab824ab152c819b')}
# {'created_at': 'Fri Jan 08 18:59:45 +0000 2021', 'id_str': '1347619016899231745', 'text': '@LDL_BR E daí? Python tem o YouTube', '_id': ObjectId('5ff8aba9aab824ab152c819c')}
# {'created_at': 'Fri Jan 08 18:59:46 +0000 2021', 'id_str': '1347619018535010306', 'text': 'RT @yvesalexandre: More push back on the idea that pseudonymized genomic data stored on unaudited servers of a foreign government are anony…', '_id': ObjectId('5ff8aba9aab824ab152c819d')}
# {'created_at': 'Fri Jan 08 18:59:49 +0000 2021', 'id_str': '1347619034322370563', 'text': 'RT @Kada_soulayman: Time : 2021-01-08T17:32:53.2724137Z\n\n#Coding Test now.\n#Someone #dark #Python #C++ #Telegram #facebook #twitter #instag…', '_id': ObjectId('5ff8abadaab824ab152c819e')}
# {'created_at': 'Fri Jan 08 18:59:51 +0000 2021', 'id_str': '1347619042262134784', 'text': 'The assert statement is a powerful #debugging tool in #Python that can be used to return an error if a certain cond… https://t.co/dWAfwAWdjn', '_id': ObjectId('5ff8abafaab824ab152c819f')}
# {'created_at': 'Fri Jan 08 18:59:52 +0000 2021', 'id_str': '1347619046842380288', 'text': "C'est si galère de trouver, et c'est pour bientôt (février...)", '_id': ObjectId('5ff8abb0aab824ab152c81a0')}
# {'created_at': 'Fri Jan 08 18:59:53 +0000 2021', 'id_str': '1347619047836315653', 'text': 'RT @yvesalexandre: More push back on the idea that pseudonymized genomic data stored on unaudited servers of a foreign government are anony…', '_id': ObjectId('5ff8abb0aab824ab152c81a1')}
# {'created_at': 'Fri Jan 08 18:59:54 +0000 2021', 'id_str': '1347619052185739264', 'text': 'Have you entered this sweepstakes to win a Sig Sauer MPX Copperhead &amp; Colt Python Revolver?\nIf you enter using this… https://t.co/hIZ8jVmaC9', '_id': ObjectId('5ff8abb1aab824ab152c81a2')}
# {'created_at': 'Fri Jan 08 18:59:55 +0000 2021', 'id_str': '1347619056841474049', 'text': 'RT @t_wada: “おすすめは「テスト駆動開発」に出てくるお題を、書籍で取り扱っているJavaやPython以外の言語で試してみること” ダイレクトマーケティングのようで申し訳ないですが、これは自信を持っておすすめできます / “どうやってコーディングを学ぶか - Mag…', '_id': ObjectId('5ff8abb2aab824ab152c81a3')}
# {'created_at': 'Fri Jan 08 18:59:59 +0000 2021', 'id_str': '1347619073698328576', 'text': 'RT @akagami_channel: 今日リサーチで得た商品知識が来年や10年後も同じように活用可。\n\nこれがアンティークの良いところ。知識が蓄積されて強くなっていきます。つまり時給が上がっていきます。\n\n「ド中古」であるがために新品のトレンドと全く関係が無い世界。最新版が…', '_id': ObjectId('5ff8abb6aab824ab152c81a4')}
# {'created_at': 'Fri Jan 08 19:00:02 +0000 2021', 'id_str': '1347619087829131266', 'text': 'RT @Kada_soulayman: Time : 2021-01-08T18:52:59.5706184Z\n\n#Coding Test now.\n#Someone #dark #Python #C++ #Telegram #facebook #twitter #instag…', '_id': ObjectId('5ff8abbaaab824ab152c81a5')}
# {'created_at': 'Fri Jan 08 19:00:06 +0000 2021', 'id_str': '1347619102492418051', 'text': 'RT @GeeknProud42: WANTED! \nSomeone who can take dictation of python/bash/LaTeX to assist me with the final year of my #PhD !\nWork is remote…', '_id': ObjectId('5ff8abbdaab824ab152c81a6')}
# {'created_at': 'Fri Jan 08 19:00:06 +0000 2021', 'id_str': '1347619102936985602', 'text': 'RT @financial_mod: 🚀🎉🎊Looking for a Financial Data API? Look No Further Than Financial Modeling Prep 🎊🎉 🚀\n\n👉A One-Stop-Shop for all your Fi…', '_id': ObjectId('5ff8abbdaab824ab152c81a7')}
# {'created_at': 'Fri Jan 08 19:00:07 +0000 2021', 'id_str': '1347619108020482055', 'text': 'One-Hot Encoding for Machine Learning with Python and Scikit-learn\n\n#neuralnetworks #neuralnetwork #deeplearning… https://t.co/JegBwXXDt9', '_id': ObjectId('5ff8abbeaab824ab152c81a8')}
# {'created_at': 'Fri Jan 08 19:00:11 +0000 2021', 'id_str': '1347619122838990849', 'text': 'RT @OmHardaha: DAY- 13  (8/1/21) \n           \nLEARNED -  not done anything ☹️\nRest &amp; cllg work\n\n #100daysofcodechallenge\n#skills #100DaysOf…', '_id': ObjectId('5ff8abc2aab824ab152c81a9')}
# {'created_at': 'Fri Jan 08 19:00:11 +0000 2021', 'id_str': '1347619122851536898', 'text': 'How Data Science is Important for eCommerce #predictiveanalytics https://t.co/iePzIypJ7i', '_id': ObjectId('5ff8abc2aab824ab152c81aa')}
# {'created_at': 'Fri Jan 08 19:00:11 +0000 2021', 'id_str': '1347619124688596996', 'text': 'RT @BadMommy4U: Oh Gawd. My jeans have gone from a snug fit to a Python kinda death grip.', '_id': ObjectId('5ff8abc2aab824ab152c81ab')}
# {'created_at': 'Fri Jan 08 19:00:11 +0000 2021', 'id_str': '1347619124407640065', 'text': '(US NEWS) Vaccine Rollout Hits Snag as Health Workers Balk at Shots\n\n“I don’t think anyone wants to be a guinea pig… https://t.co/zO56PAADq0', '_id': ObjectId('5ff8abc2aab824ab152c81ac')}
# {'created_at': 'Fri Jan 08 19:00:12 +0000 2021', 'id_str': '1347619129788923904', 'text': 'RT @MachineCurve: One-Hot Encoding for Machine Learning with Python and Scikit-learn\n\n#neuralnetworks #neuralnetwork #deeplearning #machine…', '_id': ObjectId('5ff8abc4aab824ab152c81ad')}
# {'created_at': 'Fri Jan 08 19:00:14 +0000 2021', 'id_str': '1347619137107984388', 'text': 'RT @MachineCurve: One-Hot Encoding for Machine Learning with Python and Scikit-learn\n\n#neuralnetworks #neuralnetwork #deeplearning #machine…', '_id': ObjectId('5ff8abc5aab824ab152c81ae')}
# {'created_at': 'Fri Jan 08 19:00:16 +0000 2021', 'id_str': '1347619146188648448', 'text': 'RT @MachineCurve: One-Hot Encoding for Machine Learning with Python and Scikit-learn\n\n#neuralnetworks #neuralnetwork #deeplearning #machine…', '_id': ObjectId('5ff8abc8aab824ab152c81af')}
# {'created_at': 'Fri Jan 08 19:00:18 +0000 2021', 'id_str': '1347619152249327616', 'text': 'RT @grjenkin: How Data Science is Important for eCommerce #predictiveanalytics https://t.co/iePzIypJ7i', '_id': ObjectId('5ff8abc9aab824ab152c81b0')}
# {'created_at': 'Fri Jan 08 19:00:18 +0000 2021', 'id_str': '1347619152870199297', 'text': 'Hire us to do your;\nBusiness\nStatistics\nMaths\nAssignments due\nDissertation\nBook review\nEngineering\nEssays due\nTheor… https://t.co/FCwU74Yiuf', '_id': ObjectId('5ff8abc9aab824ab152c81b1')}
# {'created_at': 'Fri Jan 08 19:00:20 +0000 2021', 'id_str': '1347619161556574210', 'text': "We help you to get your desired grade and don't worry about your online submissions anymore. Dm us for support.… https://t.co/SrWECZMRu4", '_id': ObjectId('5ff8abcbaab824ab152c81b2')}
# {'created_at': 'Fri Jan 08 19:00:20 +0000 2021', 'id_str': '1347619164157075456', 'text': 'RT @MachineCurve: One-Hot Encoding for Machine Learning with Python and Scikit-learn\n\n#neuralnetworks #neuralnetwork #deeplearning #machine…', '_id': ObjectId('5ff8abccaab824ab152c81b3')}
# {'created_at': 'Fri Jan 08 19:00:20 +0000 2021', 'id_str': '1347619164274487303', 'text': 'RT @financial_mod: 🚀🎉🎊Looking for a Financial Data API? Look No Further Than Financial Modeling Prep 🎊🎉 🚀\n\n👉A One-Stop-Shop for all your Fi…', '_id': ObjectId('5ff8abccaab824ab152c81b4')}
# {'created_at': 'Fri Jan 08 19:00:23 +0000 2021', 'id_str': '1347619175590715400', 'text': 'RT @R11RT: @Cleavon_MD @DisSci22 That’s what I want to see in my selection of a family doctor.  No respect for facts, data and probably sci…', '_id': ObjectId('5ff8abcfaab824ab152c81b5')}
# {'created_at': 'Fri Jan 08 19:00:25 +0000 2021', 'id_str': '1347619182175612931', 'text': 'RT @WritingReliable: Hire us to do your;\nBusiness\nStatistics\nMaths\nAssignments due\nDissertation\nBook review\nEngineering\nEssays due\nTheory\nP…', '_id': ObjectId('5ff8abd0aab824ab152c81b6')}
# {'created_at': 'Fri Jan 08 19:00:26 +0000 2021', 'id_str': '1347619186378420224', 'text': "RT @Jer1dah: Don't sleep on Udemy. There are financial modeling and data science courses for R200.\n\nIf you want to study a course on Udemy…", '_id': ObjectId('5ff8abd1aab824ab152c81b7')}
# {'created_at': 'Fri Jan 08 19:00:27 +0000 2021', 'id_str': '1347619190019137541', 'text': 'RT @Tanguy_lrx: Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript #github #nod…', '_id': ObjectId('5ff8abd2aab824ab152c81b8')}
# {'created_at': 'Fri Jan 08 19:00:29 +0000 2021', 'id_str': '1347619199489867776', 'text': 'Another paper which does not find rapidly fading immunity:\n\n"Our data show immune memory in at least three immunolo… https://t.co/1GAuNfDt2O', '_id': ObjectId('5ff8abd4aab824ab152c81b9')}
# {'created_at': 'Fri Jan 08 19:00:29 +0000 2021', 'id_str': '1347619201389744133', 'text': '2021-01-09 04:00:01\n仙台市\n現在の天候：所により曇り\n\u3000\u3000\u3000気温：-4℃\n#仙台の天気\n#プログラミング #Python\n#相互フォロー #フォロバ100', '_id': ObjectId('5ff8abd5aab824ab152c81ba')}
# {'created_at': 'Fri Jan 08 19:00:30 +0000 2021', 'id_str': '1347619204808142848', 'text': 'RT @R11RT: @Cleavon_MD @DisSci22 That’s what I want to see in my selection of a family doctor.  No respect for facts, data and probably sci…', '_id': ObjectId('5ff8abd6aab824ab152c81bb')}
# {'created_at': 'Fri Jan 08 19:00:32 +0000 2021', 'id_str': '1347619212496408579', 'text': 'Turner, B. M., Forstmann, B. U., Wagenmakers, E. J., Brown, S. D., Sederberg, P. B., &amp; Steyvers, M. (2013). A Bayes… https://t.co/g4S5PvT7Xe', '_id': ObjectId('5ff8abd7aab824ab152c81bc')}
# {'created_at': 'Fri Jan 08 19:00:33 +0000 2021', 'id_str': '1347619215830749184', 'text': 'Building Python modules from a wheel for Spark ETL workloads using AWS Glue 2.0 https://t.co/EFKEhbGrEN https://t.co/JWNbvKd7h6', '_id': ObjectId('5ff8abd8aab824ab152c81bd')}
# {'created_at': 'Fri Jan 08 19:00:34 +0000 2021', 'id_str': '1347619222386577410', 'text': 'Read this blog post, brought to you by Gadget Support Technologies, to learn more about the features @HPE ProLiant… https://t.co/11pNf0WTrB', '_id': ObjectId('5ff8abdaaab824ab152c81be')}
# {'created_at': 'Fri Jan 08 19:00:35 +0000 2021', 'id_str': '1347619225704267780', 'text': 'A Beginner’s Guide to #Hadoop’s Fundamentals | #BigData #Analytics #DataScience #AI #MachineLearning #ApacheSpark… https://t.co/Xv7hl0u71i', '_id': ObjectId('5ff8abdbaab824ab152c81bf')}
# {'created_at': 'Fri Jan 08 19:00:36 +0000 2021', 'id_str': '1347619229739216901', 'text': 'RT @EdKwedar: A Beginner’s Guide to #Hadoop’s Fundamentals | #BigData #Analytics #DataScience #AI #MachineLearning #ApacheSpark #IoT #Pytho…', '_id': ObjectId('5ff8abdbaab824ab152c81c0')}
# {'created_at': 'Fri Jan 08 19:00:37 +0000 2021', 'id_str': '1347619233384058883', 'text': '@BillsHelmetBar @BillsStadium Please, do not dilute its power with a cruddy beer brand. I’m with @AaronQuinn716 on… https://t.co/MES0MouoN3', '_id': ObjectId('5ff8abdcaab824ab152c81c1')}
# {'created_at': 'Fri Jan 08 19:00:39 +0000 2021', 'id_str': '1347619240619216896', 'text': 'we help ensure you get good grades in\n#PowerPoint\n#Computer science \n#Geometry\nPsychology\nSociology\n#Data analysis… https://t.co/ZCqM5ltTtF', '_id': ObjectId('5ff8abdeaab824ab152c81c2')}
# {'created_at': 'Fri Jan 08 19:00:40 +0000 2021', 'id_str': '1347619247988613121', 'text': 'RT @EdKwedar: A Beginner’s Guide to #Hadoop’s Fundamentals | #BigData #Analytics #DataScience #AI #MachineLearning #ApacheSpark #IoT #Pytho…', '_id': ObjectId('5ff8abe0aab824ab152c81c3')}
# {'created_at': 'Fri Jan 08 19:00:40 +0000 2021', 'id_str': '1347619248013774856', 'text': 'RT @EdKwedar: A Beginner’s Guide to #Hadoop’s Fundamentals | #BigData #Analytics #DataScience #AI #MachineLearning #ApacheSpark #IoT #Pytho…', '_id': ObjectId('5ff8abe0aab824ab152c81c4')}
# {'created_at': 'Fri Jan 08 19:00:46 +0000 2021', 'id_str': '1347619269878501376', 'text': 'RT @javahelponline: we help ensure you get good grades in\n#PowerPoint\n#Computer science \n#Geometry\nPsychology\nSociology\n#Data analysis\nThes…', '_id': ObjectId('5ff8abe5aab824ab152c81c5')}
# {'created_at': 'Fri Jan 08 19:00:46 +0000 2021', 'id_str': '1347619272516923393', 'text': '@AlejoToro3 Me ofrezco como analista de big data y todo eso en nacional, no falta con ver un premio en la surameric… https://t.co/hIMqwcLpOC', '_id': ObjectId('5ff8abe6aab824ab152c81c6')}
# {'created_at': 'Fri Jan 08 19:00:47 +0000 2021', 'id_str': '1347619273968115715', 'text': 'RT @energydata123: Day-11:\nPlotted the relation between income per capita and GHG emissions per capita by countries in the world in 2016. C…', '_id': ObjectId('5ff8abe6aab824ab152c81c7')}
# {'created_at': 'Fri Jan 08 19:00:47 +0000 2021', 'id_str': '1347619276690231305', 'text': '@Rice_D2KLab students working with @OpenStax developed a #datadriven approach to identifying students falling behin… https://t.co/0vwvzAIuC8', '_id': ObjectId('5ff8abe7aab824ab152c81c8')}
# {'created_at': 'Fri Jan 08 19:00:52 +0000 2021', 'id_str': '1347619295019339778', 'text': "RT @ClassicFirearm: 🚨NEW CONTEST ALERT🚨 Not one, but two prizes this time around! That's right, we're giving away a Sig Sauer MPX Copperhea…", '_id': ObjectId('5ff8abebaab824ab152c81c9')}
# {'created_at': 'Fri Jan 08 19:00:52 +0000 2021', 'id_str': '1347619296030060549', 'text': '#FadeDennis hit the toughest patch since recording data, yet is still up over 20 units. The averages will swing; pr… https://t.co/EHmkB4lUWR', '_id': ObjectId('5ff8abebaab824ab152c81ca')}
# {'created_at': 'Fri Jan 08 19:00:53 +0000 2021', 'id_str': '1347619301952548865', 'text': 'RT @MachineCurve: One-Hot Encoding for Machine Learning with Python and Scikit-learn\n\n#neuralnetworks #neuralnetwork #deeplearning #machine…', '_id': ObjectId('5ff8abedaab824ab152c81cb')}
# {'created_at': 'Fri Jan 08 19:00:55 +0000 2021', 'id_str': '1347619307040112642', 'text': 'RT @Rice_D2KLab: @Rice_D2KLab students working with @OpenStax developed a #datadriven approach to identifying students falling behind in cl…', '_id': ObjectId('5ff8abeeaab824ab152c81cc')}
# {'created_at': 'Fri Jan 08 19:00:55 +0000 2021', 'id_str': '1347619308915089410', 'text': 'I just entered to win a Sig Sauer MPX Copperhead &amp; Colt Python Revolver from @ClassicFirearm! Valued At $3500!… https://t.co/zKd0VaFkFb', '_id': ObjectId('5ff8abeeaab824ab152c81cd')}
# {'created_at': 'Fri Jan 08 19:00:55 +0000 2021', 'id_str': '1347619310970277892', 'text': 'RT @JaiyeTikolo: You know when you can’t wait to get off work to work on your pet project😂. I’m about to automate the sh**t out of my lapto…', '_id': ObjectId('5ff8abefaab824ab152c81ce')}
# {'created_at': 'Fri Jan 08 19:00:58 +0000 2021', 'id_str': '1347619320835186688', 'text': 'Challenging: At Scout we solve interesting challenges across the entire stack - web, mobile, DevOps, distributed sy… https://t.co/2T7Pqh82Lg', '_id': ObjectId('5ff8abf1aab824ab152c81cf')}
# {'created_at': 'Fri Jan 08 19:01:00 +0000 2021', 'id_str': '1347619329051914241', 'text': 'RT @Tanguy_lrx: Elon Musk is now the richest person thanks to #Tesla shares 🚙\n\n#hclswlobp #amazon #nocode #lowcode #javascript #github #nod…', '_id': ObjectId('5ff8abf3aab824ab152c81d0')}
# {'created_at': 'Fri Jan 08 19:01:00 +0000 2021', 'id_str': '1347619332143132673', 'text': 'RT @Gno83: I just entered to win a Sig Sauer MPX Copperhead &amp; Colt Python Revolver from @ClassicFirearm! Valued At $3500! #sweepstakes #Sig…', '_id': ObjectId('5ff8abf4aab824ab152c81d1')}
# {'created_at': 'Fri Jan 08 19:01:01 +0000 2021', 'id_str': '1347619332466110473', 'text': 'RT @MachineCurve: One-Hot Encoding for Machine Learning with Python and Scikit-learn\n\n#neuralnetworks #neuralnetwork #deeplearning #machine…', '_id': ObjectId('5ff8abf4aab824ab152c81d2')}
# {'created_at': 'Fri Jan 08 19:01:04 +0000 2021', 'id_str': '1347619346038853633', 'text': 'RT @DrLouiseSlater: We will be recruiting a Postdoctoral Research Associate in global computational flood hydro-morphology from 1 May 2021…', '_id': ObjectId('5ff8abf7aab824ab152c81d3')}
# {'created_at': 'Fri Jan 08 19:01:05 +0000 2021', 'id_str': '1347619351294320651', 'text': 'Hourly average speed test results\n-DL(Mb/s): 135.50 (max:142.00/min:113.00)\n-UL(Mb/s): 28.93 (max:31.20/min:25.50)… https://t.co/M6iETuCLkg', '_id': ObjectId('5ff8abf8aab824ab152c81d4')}
# {'created_at': 'Fri Jan 08 19:01:05 +0000 2021', 'id_str': '1347619352691011584', 'text': 'Blender Talk: JMeshtools,  Addons &amp; Python https://t.co/j8nGCSsn8h #b3d https://t.co/09PTxoFfSJ', '_id': ObjectId('5ff8abf9aab824ab152c81d5')}
# {'created_at': 'Fri Jan 08 19:01:07 +0000 2021', 'id_str': '1347619360366497793', 'text': '@mridul_sarkar_ This is a great idea, I don’t think it would be so hard to create a python script that can interface with a calendar', '_id': ObjectId('5ff8abfbaab824ab152c81d6')}
# {'created_at': 'Fri Jan 08 19:01:08 +0000 2021', 'id_str': '1347619363856252941', 'text': 'Check out our Python working with data  remote course on 19/01, which has a bursary of £220 per day to pay for cove… https://t.co/djtnusRgB4', '_id': ObjectId('5ff8abfcaab824ab152c81d7')}
# {'created_at': 'Fri Jan 08 19:01:08 +0000 2021', 'id_str': '1347619364950974464', 'text': 'Data Science &amp; Machine Learning Encyclopedia - 4,000 Entries by Vincent Granville https://t.co/KkFSQhdhLy #dsc_Technical #dsc_hash_t1I7O', '_id': ObjectId('5ff8abfcaab824ab152c81d8')}
# {'created_at': 'Fri Jan 08 19:01:09 +0000 2021', 'id_str': '1347619366809042946', 'text': '@CarlCasis @RicFlairNatrBoy Where will you get your python fix', '_id': ObjectId('5ff8abfcaab824ab152c81d9')}
# {'created_at': 'Fri Jan 08 19:01:11 +0000 2021', 'id_str': '1347619374925013000', 'text': '@PlayAdoptMe Reptilei\nHäufig: Eidechse, blindschleiche\nUngewöhnlich: Gecko, feuersalamander\nSelten: blaue Eidechse,… https://t.co/XFnzdNvuII', '_id': ObjectId('5ff8abfeaab824ab152c81da')}
# {'created_at': 'Fri Jan 08 19:01:11 +0000 2021', 'id_str': '1347619375365369856', 'text': 'RT @toluolawumi_: 1. Angular JS Developers needed for a 50-hour contract gig. \n\n2. Onsite Python Developers needed for a full time role at…', '_id': ObjectId('5ff8abfeaab824ab152c81db')}
# {'created_at': 'Fri Jan 08 19:01:12 +0000 2021', 'id_str': '1347619380436361220', 'text': 'RT @mariagallegobl: 🔴"Los niños y los jóvenes podrían ser el próximo grupo de riesgo del coronavirus: así lo explica Nicolás Rodríguez, ana…', '_id': ObjectId('5ff8abffaab824ab152c81dc')}
# {'created_at': 'Fri Jan 08 19:01:12 +0000 2021', 'id_str': '1347619381501681668', 'text': "We're hiring!\n\nPosition: Python Developer\nLocation: Montreal, QC\n\nIf interested then send your resume to the inbox… https://t.co/91QyW1A3Xb", '_id': ObjectId('5ff8ac00aab824ab152c81dd')}
# {'created_at': 'Fri Jan 08 19:01:14 +0000 2021', 'id_str': '1347619388191428608', 'text': '#MachineLearning #DataScience #NLP #chatbot #chatbots #ai #ArtificialIntelligence #Data #DataScientist \nHave you ev… https://t.co/ubi3fxIsuq', '_id': ObjectId('5ff8ac01aab824ab152c81de')}
# {'created_at': 'Fri Jan 08 19:01:15 +0000 2021', 'id_str': '1347619394281619456', 'text': 'RT @DataScienceCtrl: Data Science &amp; Machine Learning Encyclopedia - 4,000 Entries by Vincent Granville https://t.co/KkFSQhdhLy #dsc_Technic…', '_id': ObjectId('5ff8ac03aab824ab152c81df')}
# {'created_at': 'Fri Jan 08 19:01:16 +0000 2021', 'id_str': '1347619396362113025', 'text': 'If you plan to work as a Backend Engineer, Mav Farm is hiring.  #python #go #amazon-web-services #rest #graphql… https://t.co/93R435GsJU', '_id': ObjectId('5ff8ac03aab824ab152c81e0')}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-6a9070444200> in <module>()
#       1 # Iniciando o filtro e gravando os tweets no MongoDB
# ----> 2 mystream.filter(track=keywords)
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# ~\Anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# ~\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# ~\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# ~\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
mystream.disconnect()

# %% [markdown]
# ## Coletando os Tweets

# %% [markdown]
# ## --> Pressione o botão Stop na barra de ferramentas para encerrar a captura dos Tweets

# %% [markdown]
# ## Consultando os Dados no MongoDB

# %%
mystream.disconnect()

# %%
# Verificando um documento no collection
col.find_one()
# Out:
# {'_id': ObjectId('5eac9e8b3e660bcd8734a781'),
#  'created_at': 'Fri May 01 22:11:18 +0000 2020',
#  'id_str': '1256345476409880576',
#  'text': 'strong monty python vibes  #AnimalCrossing #ACNH #NintendoSwitch https://t.co/ZSv9R30l6G'}

# %% [markdown]
# ## Análise de Dados com Pandas e Scikit-Learn

# %%
# criando um dataset com dados retornados do MongoDB
dataset = [{"created_at": item["created_at"], "text": item["text"],} for item in col.find()]

# %%
# Importando o módulo Pandas para trabalhar com datasets em Python
import pandas as pd

# %%
# Criando um dataframe a partir do dataset 
df = pd.DataFrame(dataset)

# %%
# Imprimindo o dataframe
df
# Out:
#                          created_at  \
# 0    Fri May 01 22:11:18 +0000 2020
# 1    Fri May 01 22:11:18 +0000 2020
# 2    Fri May 01 22:11:20 +0000 2020
# 3    Fri May 01 22:11:21 +0000 2020
# 4    Fri May 01 22:11:22 +0000 2020
# 5    Fri May 01 22:11:22 +0000 2020
# 6    Fri May 01 22:11:27 +0000 2020
# 7    Fri May 01 22:11:27 +0000 2020
# 8    Fri May 01 22:11:28 +0000 2020
# 9    Fri May 01 22:11:29 +0000 2020
# 10   Fri May 01 22:11:30 +0000 2020
# 11   Fri May 01 22:11:33 +0000 2020
# 12   Fri May 01 22:11:36 +0000 2020
# 13   Fri May 01 22:11:39 +0000 2020
# 14   Fri May 01 22:11:43 +0000 2020
# 15   Fri May 01 22:11:45 +0000 2020
# 16   Fri May 01 22:11:46 +0000 2020
# 17   Fri May 01 22:11:53 +0000 2020
# 18   Fri May 01 22:11:54 +0000 2020
# 19   Fri May 01 22:11:55 +0000 2020
# 20   Fri May 01 22:11:55 +0000 2020
# 21   Fri May 01 22:11:56 +0000 2020
# 22   Fri May 01 22:11:57 +0000 2020
# 23   Fri May 01 22:11:59 +0000 2020
# 24   Fri May 01 22:11:59 +0000 2020
# 25   Fri May 01 22:11:59 +0000 2020
# 26   Fri May 01 22:12:00 +0000 2020
# 27   Fri May 01 22:12:07 +0000 2020
# 28   Fri May 01 22:12:07 +0000 2020
# 29   Fri May 01 22:12:07 +0000 2020
# ..                              ...
# 282  Fri Jan 08 19:00:40 +0000 2021
# 283  Fri Jan 08 19:00:40 +0000 2021
# 284  Fri Jan 08 19:00:46 +0000 2021
# 285  Fri Jan 08 19:00:46 +0000 2021
# 286  Fri Jan 08 19:00:47 +0000 2021
# 287  Fri Jan 08 19:00:47 +0000 2021
# 288  Fri Jan 08 19:00:52 +0000 2021
# 289  Fri Jan 08 19:00:52 +0000 2021
# 290  Fri Jan 08 19:00:53 +0000 2021
# 291  Fri Jan 08 19:00:55 +0000 2021
# 292  Fri Jan 08 19:00:55 +0000 2021
# 293  Fri Jan 08 19:00:55 +0000 2021
# 294  Fri Jan 08 19:00:58 +0000 2021
# 295  Fri Jan 08 19:01:00 +0000 2021
# 296  Fri Jan 08 19:01:00 +0000 2021
# 297  Fri Jan 08 19:01:01 +0000 2021
# 298  Fri Jan 08 19:01:04 +0000 2021
# 299  Fri Jan 08 19:01:05 +0000 2021
# 300  Fri Jan 08 19:01:05 +0000 2021
# 301  Fri Jan 08 19:01:07 +0000 2021
# 302  Fri Jan 08 19:01:08 +0000 2021
# 303  Fri Jan 08 19:01:08 +0000 2021
# 304  Fri Jan 08 19:01:09 +0000 2021
# 305  Fri Jan 08 19:01:11 +0000 2021
# 306  Fri Jan 08 19:01:11 +0000 2021
# 307  Fri Jan 08 19:01:12 +0000 2021
# 308  Fri Jan 08 19:01:12 +0000 2021
# 309  Fri Jan 08 19:01:14 +0000 2021
# 310  Fri Jan 08 19:01:15 +0000 2021
# 311  Fri Jan 08 19:01:16 +0000 2021
#
#                                                   text
# 0    strong monty python vibes  #AnimalCrossing #AC...
# 1    @George_Osborne @MattHancock Following the sci...
# 2    RT @trainer_swiftjo: بعد المصادر المهمة في بدا...
# 3    If there is one thing I've learned during my p...
# 4    Im cross the govt: has been a shambles in this...
# 5    Essential Docker for Python Flask Development\...
# 6    RT @scottsantens: Heads up, everyone. @UBDInco...
# 7    eulogic persists\n by Jared Haer\n\n#Python #G...
# 8    @lindsaysmoore @CBSNews Based on actual data, ...
# 9    RT @JordanSchachtel: Remember that Gavin Newso...
# 10   @GovInslee Fuck your testing and fuck your fal...
# 11   RT @JordanSchachtel: Remember that Gavin Newso...
# 12   RT @cybsploit: How to Create a Keylogger for L...
# 13   RT @CouponsFreeDis1: Laravel Tutorial for Begi...
# 14   RT @tforcworc: ongoing review of what data sci...
# 15   RT @JordanSchachtel: Remember that Gavin Newso...
# 16   RT @JordanSchachtel: Remember that Gavin Newso...
# 17   Outras referências importantes pra mim e tempo...
# 18   RT @JordanSchachtel: Remember that Gavin Newso...
# 19   @apranaxfortttt I think you can find this usef...
# 20   RT @RealErinCruz: No, @GavinNewsom ... you are...
# 21                                                  復活
# 22   RT @RationalDis: Buddy, you didn't say "I woul...
# 23   RT @CouponsFreeDis1: Laravel Tutorial for Begi...
# 24   RT @CouponsFreeDis1: Laravel Tutorial for Begi...
# 25   RT @CouponsFreeDis1: Laravel Tutorial for Begi...
# 26   antapodosis graphiology\n by Jared Haer\n\n#co...
# 27   RT @i_am_imoh: Day 31 of #100DaysOfCode, spent...
# 28   RT @i_am_imoh: Day 31 of #100DaysOfCode, spent...
# 29   RT @i_am_imoh: Day 31 of #100DaysOfCode, spent...
# ..                                                 ...
# 282  RT @EdKwedar: A Beginner’s Guide to #Hadoop’s ...
# 283  RT @EdKwedar: A Beginner’s Guide to #Hadoop’s ...
# 284  RT @javahelponline: we help ensure you get goo...
# 285  @AlejoToro3 Me ofrezco como analista de big da...
# 286  RT @energydata123: Day-11:\nPlotted the relati...
# 287  @Rice_D2KLab students working with @OpenStax d...
# 288  RT @ClassicFirearm: 🚨NEW CONTEST ALERT🚨 Not on...
# 289  #FadeDennis hit the toughest patch since recor...
# 290  RT @MachineCurve: One-Hot Encoding for Machine...
# 291  RT @Rice_D2KLab: @Rice_D2KLab students working...
# 292  I just entered to win a Sig Sauer MPX Copperhe...
# 293  RT @JaiyeTikolo: You know when you can’t wait ...
# 294  Challenging: At Scout we solve interesting cha...
# 295  RT @Tanguy_lrx: Elon Musk is now the richest p...
# 296  RT @Gno83: I just entered to win a Sig Sauer M...
# 297  RT @MachineCurve: One-Hot Encoding for Machine...
# 298  RT @DrLouiseSlater: We will be recruiting a Po...
# 299  Hourly average speed test results\n-DL(Mb/s): ...
# 300  Blender Talk: JMeshtools,  Addons &amp; Python...
# 301  @mridul_sarkar_ This is a great idea, I don’t ...
# 302  Check out our Python working with data  remote...
# 303  Data Science &amp; Machine Learning Encycloped...
# 304  @CarlCasis @RicFlairNatrBoy Where will you get...
# 305  @PlayAdoptMe Reptilei\nHäufig: Eidechse, blind...
# 306  RT @toluolawumi_: 1. Angular JS Developers nee...
# 307  RT @mariagallegobl: 🔴"Los niños y los jóvenes ...
# 308  We're hiring!\n\nPosition: Python Developer\nL...
# 309  #MachineLearning #DataScience #NLP #chatbot #c...
# 310  RT @DataScienceCtrl: Data Science &amp; Machin...
# 311  If you plan to work as a Backend Engineer, Mav...
#
# [312 rows x 2 columns]

# %%
# Importando o módulo Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer

# %%
# Usando o método CountVectorizer para criar uma matriz de documentos
cv = CountVectorizer()
count_matrix = cv.fit_transform(df.text)

# %%
# Contando o número de ocorrências das principais palavras em nosso dataset
word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#                word  count
# 0                rt    198
# 1             https    150
# 2                co    149
# 3            python    133
# 4               the    112
# 5                to     89
# 6              data     86
# 7               and     79
# 8                of     59
# 9               for     58
# 10               on     52
# 11              you     51
# 12               in     50
# 13             with     49
# 14               is     49
# 15          science     48
# 16              are     28
# 17             that     28
# 18               ai     26
# 19              amp     26
# 20               de     26
# 21             this     26
# 22            there     25
# 23               at     25
# 24         learning     25
# 25        analytics     25
# 26             from     24
# 27  machinelearning     24
# 28              big     24
# 29               by     23
# 30               no     23
# 31              now     22
# 32              can     21
# 33               it     21
# 34               or     21
# 35      datascience     20
# 36          machine     19
# 37               we     19
# 38              iot     19
# 39          bigdata     18
# 40              one     18
# 41       javascript     18
# 42             your     17
# 43    100daysofcode     17
# 44               my     16
# 45             time     16
# 46               so     14
# 47           newsom     14
# 48  jordanschachtel     13
# 49             code     13

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
